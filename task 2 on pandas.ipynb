# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Santh\\OneDrive\\Documents\\Desktop\\names2.csv")
df
# Out:
#          name  age m/f    addrees
# 0    santhosh   23   m  hyderabad
# 1       shiva   24   m    kolkata
# 2     asmitha   22   f      vizag
# 3       sneha   21   f     kerala
# 4  malikarjun   24   m     mumbai

# %%
fav_colour = ['blue','black','white','green','yellow'] 
df["fav_colour"] = fav_colour
df
# Out:
#          name  age m/f    addrees fav_colour
# 0    santhosh   23   m  hyderabad       blue
# 1       shiva   24   m    kolkata      black
# 2     asmitha   22   f      vizag      white
# 3       sneha   21   f     kerala      green
# 4  malikarjun   24   m     mumbai     yellow

# %%
df.to_csv('file.csv')

# %%
df
# Out:
#          name  age m/f    addrees fav_colour
# 0    santhosh   23   m  hyderabad       blue
# 1       shiva   24   m    kolkata      black
# 2     asmitha   22   f      vizag      white
# 3       sneha   21   f     kerala      green
# 4  malikarjun   24   m     mumbai     yellow

# %%
df.set_index('name',inplace = True)#Here making name as index
df
# Out:
#             age m/f    addrees fav_colour
# name
# santhosh     23   m  hyderabad       blue
# shiva        24   m    kolkata      black
# asmitha      22   f      vizag      white
# sneha        21   f     kerala      green
# malikarjun   24   m     mumbai     yellow

# %%
df
# Out:
#             age m/f    addrees fav_colour
# name
# santhosh     23   m  hyderabad       blue
# shiva        24   m    kolkata      black
# asmitha      22   f      vizag      white
# sneha        21   f     kerala      green
# malikarjun   24   m     mumbai     yellow

# %%
df.sort_index(ascending = True)#we are doing in ascending order
# Out:
#             age m/f    addrees fav_colour
# name
# asmitha      22   f      vizag      white
# malikarjun   24   m     mumbai     yellow
# santhosh     23   m  hyderabad       blue
# shiva        24   m    kolkata      black
# sneha        21   f     kerala      green
